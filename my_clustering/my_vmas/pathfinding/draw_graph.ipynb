# %%
# csv 정렬 방법들
# df = df.sort_values(by='n_targets')
# df = df.sort_values(by='n_targets', ascending=False)
# df = df.sort_values(by=['n_targets', 'time'])
# df.to_csv('sorted_output.csv', index=False)

# %% [markdown]
# 데이터 정렬

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('/home/ksh-server/workspace/ICUFN/my_clustering/my_vmas/pathfinding/data')

df = pd.read_csv('./data/clust_data_output.csv')

# n_targets 기준으로 정렬
df_sorted = df.sort_values(by='n_targets').reset_index(drop=True)

# 정렬된 파일로 저장
df_sorted.to_csv('./data/clust_data_output.csv', index=False)

# %%
df = pd.read_csv('./data/ortools_data_output.csv')

# n_targets 기준으로 정렬
df_sorted = df.sort_values(by='n_targets').reset_index(drop=True)

# 정렬된 파일로 저장
df_sorted.to_csv('./data/ortools_data_output.csv', index=False)

# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt
import sys
sys.path.append('/home/ksh-server/workspace/ICUFN/my_clustering/my_vmas/pathfinding/data')

df = pd.read_csv('./data/clust_data_output.csv')

# 리스트 컬럼 파싱
df['targets_per_agent'] = df['targets_per_agent'].apply(ast.literal_eval)
df['locations'] = df['locations'].apply(ast.literal_eval)

# 각각 따로 변수로 받기
n_targets = df['n_targets'].tolist()
n_agents = df['n_agents'].tolist()
times = df['time'].tolist()
targets_per_agent = df['targets_per_agent'].tolist()
locations = df['locations'].tolist()

# x축: n_targets, y축: time
plt.figure(figsize=(10, 6))
plt.scatter(n_targets, times, s=100, alpha=1)
# plt.plot(n_targets, times, alpha=0.3)  # 연결선 (선택)

plt.title('')
plt.xlabel('Number of Targets', fontsize=24)
plt.ylabel('Processing Time (seconds)', fontsize=24)
plt.tick_params(labelsize=24)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sys.path.append('/home/ksh-server/workspace/ICUFN/my_clustering/my_vmas/pathfinding/data')

df = pd.read_csv('./data/ortools_data_output.csv')

# 리스트 컬럼 파싱
df['targets_per_agent'] = df['targets_per_agent'].apply(ast.literal_eval)
df['locations'] = df['locations'].apply(ast.literal_eval)

# 각각 따로 변수로 받기
n_targets = df['n_targets'].tolist()
n_agents = df['n_agents'].tolist()
times = df['time'].tolist()
targets_per_agent = df['targets_per_agent'].tolist()
locations = df['locations'].tolist()

# x축: n_targets, y축: time
plt.figure(figsize=(10, 6))
plt.scatter(n_targets, times, s=100, alpha=1)
# plt.plot(n_targets, times, alpha=0.3)  # 연결선 (선택)

plt.title('')
plt.xlabel('Number of Targets', fontsize=24)
plt.ylabel('Processing Time (seconds)', fontsize=24)
plt.tick_params(labelsize=24)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt
import sys
sys.path.append('/home/ksh-server/workspace/ICUFN/my_clustering/my_vmas/pathfinding/data')

df_clust = pd.read_csv('./data/clust_data_output.csv')

# 리스트 컬럼 파싱
df_clust['targets_per_agent'] = df_clust['targets_per_agent'].apply(ast.literal_eval)
df_clust['locations'] = df_clust['locations'].apply(ast.literal_eval)

# 각각 따로 변수로 받기
n_targets_clust = df_clust['n_targets'].tolist()
n_agents_clust = df_clust['n_agents'].tolist()
times_clust = df_clust['time'].tolist()
targets_per_agent_clust = df_clust['targets_per_agent'].tolist()
locations_clust = df_clust['locations'].tolist()
   

# ortools
df_ortools = pd.read_csv('./data/ortools_data_output.csv')

# 리스트 컬럼 파싱
df_ortools['targets_per_agent'] = df_ortools['targets_per_agent'].apply(ast.literal_eval)
df_ortools['locations'] = df_ortools['locations'].apply(ast.literal_eval)

# 각각 따로 변수로 받기
n_targets_ortools = df_ortools['n_targets'].tolist()
n_agents_ortools = df_ortools['n_agents'].tolist()
times_ortools = df_ortools['time'].tolist()
targets_per_agent_ortools = df_ortools['targets_per_agent'].tolist()
locations_ortools = df_ortools['locations'].tolist()

size = 20

# 클러스트 평균 시간
n_targets_clust_avg = []
times_clust_avg = []
for i in range(size, len(times_clust)+1, size):
    n_targets_clust_avg.append(n_targets_clust[i-size])
    times_clust_avg.append(sum(times_clust[i-size:i]) / size)
    
# ortools avg time
n_targets_ortools_avg = []
times_ortools_avg = []
for i in range(size, len(times_ortools)+1, size):
    n_targets_ortools_avg.append(n_targets_ortools[i-size])
    times_ortools_avg.append(sum(times_ortools[i-size:i]) / size)

# x축: n_targets, y축: time
plt.figure(figsize=(10, 6))

plt.scatter(n_targets_clust_avg, times_clust_avg, s=100, alpha=1, label='Clustering+TSP')
plt.scatter(n_targets_ortools_avg, times_ortools_avg, s=100, alpha=1, label='TSP')

plt.plot(n_targets_clust_avg, times_clust_avg, linewidth=3, alpha=1)  # 연결선 (선택)
plt.plot(n_targets_ortools_avg, times_ortools_avg, linewidth=3, alpha=1)  # 연결선 (선택)

plt.title('')
plt.xlabel('Number of Targets', fontsize=24)
plt.ylabel('Processing Time (seconds)', fontsize=24)
plt.tick_params(labelsize=24)
plt.grid(True)
plt.legend(fontsize=24)
plt.tight_layout()
plt.show()

# %%
sys.path.append('/home/ksh-server/workspace/ICUFN/my_clustering/my_vmas/pathfinding/data')

df = pd.read_csv('./data/only_clust_data_output.csv')

# 리스트 컬럼 파싱
df['targets_per_agent'] = df['targets_per_agent'].apply(ast.literal_eval)
#df['locations'] = df['targets_per_agent'].apply(ast.literal_eval)

# 각각 따로 변수로 받기
n_targets = df['n_targets'].tolist()
n_agents = df['n_agents'].tolist()
times = df['time'].tolist()
targets_per_agent = df['targets_per_agent'].tolist()
#locations = df['locations'].tolist()

# x축: n_targets, y축: time
plt.figure(figsize=(10, 6))
plt.scatter(n_targets, times, alpha=0.7, label='Execution Time per Target Count')
plt.plot(n_targets, times, alpha=0.3)  # 연결선 (선택)

plt.title('Execution Time vs. Number of Targets')
plt.xlabel('Number of Targets (n_targets)')
plt.ylabel('Execution Time (seconds)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt
import sys
sys.path.append('/home/ksh-server/workspace/ICUFN/my_clustering/my_vmas/pathfinding/data')

df_clust = pd.read_csv('./data/clust_data_output.csv')

# 리스트 컬럼 파싱
df_clust['targets_per_agent'] = df_clust['targets_per_agent'].apply(ast.literal_eval)
df_clust['locations'] = df_clust['locations'].apply(ast.literal_eval)

# 각각 따로 변수로 받기
n_targets_clust = df_clust['n_targets'].tolist()
n_agents_clust = df_clust['n_agents'].tolist()
times_clust = df_clust['time'].tolist()
targets_per_agent_clust = df_clust['targets_per_agent'].tolist()
locations_clust = df_clust['locations'].tolist()
   

# ortools
df_ortools = pd.read_csv('./data/ortools_data_output.csv')

# 리스트 컬럼 파싱
df_ortools['targets_per_agent'] = df_ortools['targets_per_agent'].apply(ast.literal_eval)
df_ortools['locations'] = df_ortools['locations'].apply(ast.literal_eval)

# 각각 따로 변수로 받기
n_targets_ortools = df_ortools['n_targets'].tolist()
n_agents_ortools = df_ortools['n_agents'].tolist()
times_ortools = df_ortools['time'].tolist()
targets_per_agent_ortools = df_ortools['targets_per_agent'].tolist()
locations_ortools = df_ortools['locations'].tolist()

size = 20

# 클러스트 평균 시간
n_targets_clust_avg = []
times_clust_avg = []
for i in range(size, len(times_clust)+1, size):
    n_targets_clust_avg.append(n_targets_clust[i-size])
    times_clust_avg.append(sum(times_clust[i-size:i]) / size)
    
# ortools avg time
n_targets_ortools_avg = []
times_ortools_avg = []
for i in range(size, len(times_ortools)+1, size):
    n_targets_ortools_avg.append(n_targets_ortools[i-size])
    times_ortools_avg.append(sum(times_ortools[i-size:i]) / size)

# x축: n_targets, y축: time
plt.figure(figsize=(10, 6))

plt.scatter(n_targets_clust, times_clust, alpha=0.7, label='Execution Time per Target Count of Clust + TSP')
plt.scatter(n_targets_ortools, times_ortools, alpha=0.7, label='Execution Time per Target Count of ortools')
plt.scatter(n_targets_clust_avg, times_clust_avg, alpha=0.7, label='clust avg')
plt.scatter(n_targets_ortools_avg, times_ortools_avg, alpha=0.7, label='ortools avg')

plt.plot(n_targets_clust_avg, times_clust_avg, alpha=0.3)  # 연결선 (선택)
plt.plot(n_targets_ortools_avg, times_ortools_avg, alpha=0.3)  # 연결선 (선택)

plt.title('Execution Time vs. Number of Targets')
plt.xlabel('Number of Targets (n_targets)')
plt.ylabel('Execution Time (seconds)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
print(times_clust_avg)
print(times_ortools_avg)
# Out:
# [0.07875503301620482, 0.15259412527084348, 0.31118927001953123, 0.4137028336524963, 0.46727949380874634, 0.6353183507919311, 0.7601500272750854, 0.7687283277511596, 0.9871023178100586, 1.0368520140647888, 1.1131952047348022, 1.295211136341095]
# [0.44644535779953004, 4.646480369567871, 20.90631709098816, 48.956454801559445, 93.67880288362502, 190.92417778968812, 314.61118750572206, 488.5441275835037, 696.1403979897499, 928.8407111406326, 1280.0053188323975, 1625.8503612995148]

# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt
import sys
sys.path.append('/home/ksh-server/workspace/ICUFN/my_clustering/my_vmas/pathfinding/data')

df_clust = pd.read_csv('./data/clust_data_output.csv')

# 리스트 컬럼 파싱
df_clust['targets_per_agent'] = df_clust['targets_per_agent'].apply(ast.literal_eval)
df_clust['locations'] = df_clust['locations'].apply(ast.literal_eval)

# 각각 따로 변수로 받기
n_targets_clust = df_clust['n_targets'].tolist()
n_agents_clust = df_clust['n_agents'].tolist()
times_clust = df_clust['time'].tolist()
targets_per_agent_clust = df_clust['targets_per_agent'].tolist()
locations_clust = df_clust['locations'].tolist()
   

# ortools
df_ortools = pd.read_csv('./data/ortools_data_output.csv')

# 리스트 컬럼 파싱
df_ortools['targets_per_agent'] = df_ortools['targets_per_agent'].apply(ast.literal_eval)
df_ortools['locations'] = df_ortools['locations'].apply(ast.literal_eval)

# 각각 따로 변수로 받기
n_targets_ortools = df_ortools['n_targets'].tolist()
n_agents_ortools = df_ortools['n_agents'].tolist()
times_ortools = df_ortools['time'].tolist()
targets_per_agent_ortools = df_ortools['targets_per_agent'].tolist()
locations_ortools = df_ortools['locations'].tolist()

# x축: n_targets, y축: time
plt.figure(figsize=(10, 6))

plt.scatter(n_targets_clust, times_clust, alpha=0.7, label='Execution Time per Target Count of Clust + TSP')
plt.scatter(n_targets_ortools, times_ortools, alpha=0.7, label='Execution Time per Target Count of ortools')


plt.title('Execution Time vs. Number of Targets')
plt.xlabel('Number of Targets (n_targets)')
plt.ylabel('Execution Time (seconds)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt
import numpy as np

# CSV 파일 로드 및 리스트 파싱
df = pd.read_csv('./data/ortools_data_output.csv')
df['targets_per_agent'] = df['targets_per_agent'].apply(ast.literal_eval)
df['locations'] = df['locations'].apply(ast.literal_eval)

# n_targets 별 평균 및 표준편차 계산
grouped = df.groupby('n_targets')['time']
mean_times = grouped.mean()
std_times = grouped.std()  # 또는 .sem() 으로 표준오차

# 막대그래프 그리기
plt.figure(figsize=(10, 6))
plt.bar(mean_times.index, mean_times.values, yerr=std_times.values, 
        capsize=5, alpha=0.7, color='skyblue', label='Average Execution Time')

plt.title('Average Execution Time per Number of Targets (with Std Dev)')
plt.xlabel('Number of Targets (n_targets)')
plt.ylabel('Execution Time (seconds)')
plt.grid(True, axis='y')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 불러오기
df = pd.read_csv('./data/ortools_data_output.csv')
df['targets_per_agent'] = df['targets_per_agent'].apply(ast.literal_eval)
df['locations'] = df['locations'].apply(ast.literal_eval)

# 박스플롯 그리기
plt.figure(figsize=(10, 6))
sns.boxplot(x='n_targets', y='time', data=df, palette='Blues')

plt.title('Execution Time Distribution by Number of Targets')
plt.xlabel('Number of Targets (n_targets)')
plt.ylabel('Execution Time (seconds)')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1005030/2169556929.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='n_targets', y='time', data=df, palette='Blues')

# %%
import pandas as pd
import ast
import matplotlib.pyplot as plt
import seaborn as sns

# Clust 데이터 로드
df_clust = pd.read_csv('./data/clust_data_output.csv')
df_clust['targets_per_agent'] = df_clust['targets_per_agent'].apply(ast.literal_eval)
df_clust['locations'] = df_clust['locations'].apply(ast.literal_eval)
df_clust['method'] = 'Clust + TSP'  # 방법 이름 추가

# Ortools 데이터 로드
df_ortools = pd.read_csv('./data/ortools_data_output.csv')
df_ortools['targets_per_agent'] = df_ortools['targets_per_agent'].apply(ast.literal_eval)
df_ortools['locations'] = df_ortools['locations'].apply(ast.literal_eval)
df_ortools['method'] = 'Ortools'  # 방법 이름 추가

# 두 데이터 합치기
df_all = pd.concat([df_clust, df_ortools], ignore_index=True)

# 박스플롯 그리기
plt.figure(figsize=(12, 6))
sns.boxplot(x='n_targets', y='time', hue='method', data=df_all, palette='Set2')

plt.title('Execution Time Comparison by Number of Targets')
plt.xlabel('Number of Targets (n_targets)')
plt.ylabel('Execution Time (seconds)')
plt.grid(True, axis='y')
plt.legend(title='Method')
plt.tight_layout()
plt.show()
